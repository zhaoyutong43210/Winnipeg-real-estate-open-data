# %%
from wpgdata.analysis import data_analyser
import matplotlib.pyplot as plt
import numpy as np

# %%
dz = data_analyser()

# %%
data = dz.load_data()

# %%
data
# Out:
#         Unnamed: 0    No       Property Address  Roll Number
# 0                0     0        201 BISMARCK ST   9005505000  \
# 1                1     1          100 KANATA ST   9000106000
# 2                2     2      118 MELROSE AVE E   9000097000
# 3                3     3      122 MELROSE AVE E   9000097500
# 4                4     4      124 MELROSE AVE E   9000098000
# ...            ...   ...                    ...          ...
# 123389        4079  4079  105 - 450 YOUVILLE ST   6093270700
# 123390        4080  4080  107 - 450 YOUVILLE ST   6093270900
# 123391        4081  4081  112 - 450 YOUVILLE ST   6093271400
# 123392        4082  4082  202 - 450 YOUVILLE ST   6093271600
# 123393        4083  4083  211 - 450 YOUVILLE ST   6093272500
#
#            Building Type  Sale Year Sale Month Sale Price
# 0             ONE STOREY       2010         10   $215,500  \
# 1             TWO STOREY       2011          3   $165,000
# ...

# %%
d = np.array(data['Sale Price'].replace('[\$,]', '', regex=True).astype(float))
d
# Out:
# array([215500., 165000., 106000., ..., 340000., 352000., 323000.])

# %%
plt.hist(d, bins = 500)
# Out:
# (array([2.480e+02, 6.000e+01, 1.220e+02, 2.010e+02, 3.320e+02, 4.380e+02,
#         6.310e+02, 8.270e+02, 1.169e+03, 9.940e+02, 1.667e+03, 2.240e+03,
#         3.116e+03, 3.403e+03, 4.161e+03, 4.604e+03, 5.571e+03, 4.709e+03,
#         4.324e+03, 4.971e+03, 6.221e+03, 5.238e+03, 5.672e+03, 5.349e+03,
#         5.213e+03, 5.695e+03, 4.357e+03, 3.463e+03, 3.546e+03, 3.679e+03,
#         3.065e+03, 3.020e+03, 2.618e+03, 2.918e+03, 2.185e+03, 2.061e+03,
#         1.611e+03, 1.965e+03, 1.388e+03, 1.133e+03, 1.074e+03, 9.780e+02,
#         7.860e+02, 6.300e+02, 5.470e+02, 5.190e+02, 4.440e+02, 3.700e+02,
#         3.240e+02, 3.160e+02, 2.980e+02, 2.530e+02, 1.900e+02, 1.750e+02,
#         1.830e+02, 1.460e+02, 1.220e+02, 1.030e+02, 1.780e+02, 8.900e+01,
#         9.200e+01, 7.300e+01, 7.900e+01, 5.900e+01, 6.400e+01, 5.300e+01,
#         9.500e+01, 4.600e+01, 3.100e+01, 4.400e+01, 5.200e+01, 5.800e+01,
#         4.100e+01, 3.800e+01, 3.600e+01, 4.700e+01, 1.600e+01, 3.000e+01,
# ...
